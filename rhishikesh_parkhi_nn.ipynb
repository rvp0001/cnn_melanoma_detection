# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
##Importing all relevant Libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## Google drive mount :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Unzip files
# !unzip -q /content/gdrive/My\ Drive/CNN_Assignment/CNN_assignment

# %%
#List directoy for gdrive mapped
# !ls
# Out:
#  gdrive   sample_data  'Skin cancer ISIC The International Skin Imaging Collaboration'

# %%
#List test train librarues
# !ls "Skin cancer ISIC The International Skin Imaging Collaboration"
# Out:
# Test  Train

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# define the path for train and test images
data_dir_train = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
#print image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
## define batch size and image dimensions as required
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## writing training dataset here with seed and image dimensions 180*180 while writing dataset using 80 / 20 split

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## writing validation dataset here with seed and image dimensions 180*180 while writing dataset using 80 / 20 split
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List of all the classes of skin cancer and store them in a list which are names of directories.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
#plot one image of each class using matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Define model with 2 convolution,1 maxpool,1 dense and 1 final dense with 9 classes
num_classes = 9

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### defining loss and optimiser
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
## train model with 20 epochs and save history
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 26s 84ms/step - loss: 1.9412 - accuracy: 0.2796 - val_loss: 1.6819 - val_accuracy: 0.4004
# Epoch 2/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.6035 - accuracy: 0.4369 - val_loss: 1.4757 - val_accuracy: 0.5101
# Epoch 3/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.4932 - accuracy: 0.4660 - val_loss: 1.4837 - val_accuracy: 0.5034
# Epoch 4/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3271 - accuracy: 0.5301 - val_loss: 1.4665 - val_accuracy: 0.4989
# Epoch 5/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.2318 - accuracy: 0.5631 - val_loss: 1.4063 - val_accuracy: 0.5280
# Epoch 6/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.1577 - accuracy: 0.5876 - val_loss: 1.4016 - val_accuracy: 0.5302
# Epoch 7/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.0840 - accuracy: 0.6049 - val_loss: 1.5413 - val_accuracy: 0.5459
# Epoch 8/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.9998 - accuracy: 0.6429 - val_loss: 1.5150 - val_accuracy: 0.4989
# Epoch 9/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9563 - accuracy: 0.6574 - val_loss: 1.5712 - val_accuracy: 0.5078
# Epoch 10/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.8553 - accuracy: 0.6920 - val_loss: 1.7157 - val_accuracy: 0.5145
# Epoch 11/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.7729 - accuracy: 0.7227 - val_loss: 2.0367 - val_accuracy: 0.5078
# Epoch 12/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.7696 - accuracy: 0.7243 - val_loss: 1.7240 - val_accuracy: 0.5526
# Epoch 13/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5962 - accuracy: 0.7824 - val_loss: 1.8950 - val_accuracy: 0.5414
# Epoch 14/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5206 - accuracy: 0.8175 - val_loss: 2.4307 - val_accuracy: 0.4966
# Epoch 15/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4708 - accuracy: 0.8343 - val_loss: 1.9427 - val_accuracy: 0.4787
# Epoch 16/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4241 - accuracy: 0.8471 - val_loss: 2.4620 - val_accuracy: 0.5235
# Epoch 17/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3719 - accuracy: 0.8538 - val_loss: 2.3042 - val_accuracy: 0.4899
# Epoch 18/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3637 - accuracy: 0.8666 - val_loss: 2.3209 - val_accuracy: 0.5168
# Epoch 19/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4394 - accuracy: 0.8465 - val_loss: 2.3543 - val_accuracy: 0.5369
# Epoch 20/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3338 - accuracy: 0.8739 - val_loss: 2.3329 - val_accuracy: 0.5213

# %% [markdown]
# ### Visualizing training results

# %%
## plot training and validation  accuraacy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# Training accuracy is high and validation accuracy is not increasing after 0.55.This indicates that model is overfitting.This is because of limited data used in training.
#
#
# 1.   We need to use augmentation to increase number of images to make dataset big to reduce overfitting.
# 2.   Droput
# 3.   SMOTE to reduce class imbalance

# %%
# Image augumentation is used to reduce overfitting.We use image flipping,rotation and zoom.This will help reduce overfitting.
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
#  visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model with augmentation and drop out

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## compile model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## train  model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 34ms/step - loss: 2.1100 - accuracy: 0.2059 - val_loss: 2.0245 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.9164 - accuracy: 0.2907 - val_loss: 1.8333 - val_accuracy: 0.3289
# Epoch 3/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.6094 - accuracy: 0.4364 - val_loss: 1.5250 - val_accuracy: 0.4832
# Epoch 4/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.4585 - accuracy: 0.5006 - val_loss: 1.4384 - val_accuracy: 0.5034
# Epoch 5/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.4203 - accuracy: 0.5095 - val_loss: 1.4539 - val_accuracy: 0.4855
# Epoch 6/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.3962 - accuracy: 0.5134 - val_loss: 1.4337 - val_accuracy: 0.5056
# Epoch 7/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.3467 - accuracy: 0.5279 - val_loss: 1.3916 - val_accuracy: 0.5280
# Epoch 8/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.3144 - accuracy: 0.5368 - val_loss: 1.3983 - val_accuracy: 0.5257
# Epoch 9/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.3055 - accuracy: 0.5279 - val_loss: 1.3146 - val_accuracy: 0.5481
# Epoch 10/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.2857 - accuracy: 0.5491 - val_loss: 1.4202 - val_accuracy: 0.5078
# Epoch 11/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.2950 - accuracy: 0.5458 - val_loss: 1.3486 - val_accuracy: 0.5145
# Epoch 12/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.2208 - accuracy: 0.5642 - val_loss: 1.4345 - val_accuracy: 0.5391
# Epoch 13/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.2327 - accuracy: 0.5603 - val_loss: 1.4659 - val_accuracy: 0.4787
# Epoch 14/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.1854 - accuracy: 0.5720 - val_loss: 1.3841 - val_accuracy: 0.5213
# Epoch 15/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.1497 - accuracy: 0.5748 - val_loss: 1.3039 - val_accuracy: 0.5570
# Epoch 16/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.1252 - accuracy: 0.5893 - val_loss: 1.2404 - val_accuracy: 0.5414
# Epoch 17/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.0978 - accuracy: 0.5965 - val_loss: 1.2942 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.1152 - accuracy: 0.5910 - val_loss: 1.3257 - val_accuracy: 0.5503
# Epoch 19/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.0746 - accuracy: 0.5943 - val_loss: 1.3346 - val_accuracy: 0.5280
# Epoch 20/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.1003 - accuracy: 0.5938 - val_loss: 1.3146 - val_accuracy: 0.5459

# %% [markdown]
# ### Visualizing the results

# %%
## plot training and validation  accuraacy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
# #### *****Validation accuracy has improved significantly post data augmentation and dropout significantly.*****

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
len(path_list)
# Out:
# 2239

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path                 Label
# 0     Skin cancer ISIC The International Skin Imagin...     actinic keratosis
# 1     Skin cancer ISIC The International Skin Imagin...     actinic keratosis
# 2     Skin cancer ISIC The International Skin Imagin...     actinic keratosis
# 3     Skin cancer ISIC The International Skin Imagin...     actinic keratosis
# 4     Skin cancer ISIC The International Skin Imagin...     actinic keratosis
# ...                                                 ...                   ...
# 2234  Skin cancer ISIC The International Skin Imagin...  basal cell carcinoma
# 2235  Skin cancer ISIC The International Skin Imagin...  basal cell carcinoma
# 2236  Skin cancer ISIC The International Skin Imagin...  basal cell carcinoma
# 2237  Skin cancer ISIC The International Skin Imagin...  basal cell carcinoma
# 2238  Skin cancer ISIC The International Skin Imagin...  basal cell carcinoma
#
# [2239 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# split into input and output elements
X, y = original_df['Path'], original_df['Label']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=0, n=114 (5.092%)
# Class=2, n=95 (4.243%)
# Class=6, n=77 (3.439%)
# Class=8, n=139 (6.208%)
# Class=4, n=357 (15.945%)
# Class=3, n=438 (19.562%)
# Class=5, n=462 (20.634%)
# Class=7, n=181 (8.084%)
# Class=1, n=376 (16.793%)

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
# #### *** Class number 6 has least number of samples(seborrheic keratosis)
# #### - Which classes dominate the data in terms proportionate number of samples?
# #### *** Class number 5,3,4,1 has dominate number of samples pigmented benign
#
# #### keratosis
# #### melanoma
# #### basal cell carcinoma
# #### nevus

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
#Install augmentor
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AD86C3C20B0>: 100%|██████████| 500/500 [00:19<00:00, 26.18 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AD85869F220>: 100%|██████████| 500/500 [00:19<00:00, 25.55 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AD8DFFCF5B0>: 100%|██████████| 500/500 [00:20<00:00, 23.91 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7AD85866D630>: 100%|██████████| 500/500 [01:22<00:00,  6.08 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3008x2000 at 0x7AD858508250>: 100%|██████████| 500/500 [01:16<00:00,  6.54 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AD85853B6D0>: 100%|██████████| 500/500 [00:15<00:00, 33.16 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7AD858508880>: 100%|██████████| 500/500 [00:38<00:00, 13.09 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AD85863C580>: 100%|██████████| 500/500 [00:15<00:00, 32.04 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AD85866DED0>: 100%|██████████| 500/500 [00:16<00:00, 31.08 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-35-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
#new label counts for each class
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# Added 500 images to all the classes to maintain some class balance.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
# create training DS post SMOTE
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
# create training DS post SMOTE
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation', ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
# Create model with pisel rescaling

AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## compile model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Train model 30 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 45s 59ms/step - loss: 1.9914 - accuracy: 0.2641 - val_loss: 1.5411 - val_accuracy: 0.4024
# Epoch 2/30
# 169/169 [==============================] - 5s 32ms/step - loss: 1.4046 - accuracy: 0.4638 - val_loss: 1.3487 - val_accuracy: 0.4796
# Epoch 3/30
# 169/169 [==============================] - 5s 29ms/step - loss: 1.2289 - accuracy: 0.5449 - val_loss: 1.2332 - val_accuracy: 0.5583
# Epoch 4/30
# 169/169 [==============================] - 5s 32ms/step - loss: 1.0547 - accuracy: 0.6142 - val_loss: 1.0614 - val_accuracy: 0.5895
# Epoch 5/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.9098 - accuracy: 0.6647 - val_loss: 0.9790 - val_accuracy: 0.6563
# Epoch 6/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.7207 - accuracy: 0.7417 - val_loss: 0.9503 - val_accuracy: 0.6592
# Epoch 7/30
# 169/169 [==============================] - 5s 31ms/step - loss: 0.6116 - accuracy: 0.7838 - val_loss: 0.8445 - val_accuracy: 0.6964
# Epoch 8/30
# 169/169 [==============================] - 5s 32ms/step - loss: 0.5324 - accuracy: 0.8088 - val_loss: 0.8252 - val_accuracy: 0.7298
# Epoch 9/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4412 - accuracy: 0.8401 - val_loss: 0.8773 - val_accuracy: 0.7298
# Epoch 10/30
# 169/169 [==============================] - 5s 32ms/step - loss: 0.3724 - accuracy: 0.8693 - val_loss: 0.8686 - val_accuracy: 0.7350
# Epoch 11/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.4123 - accuracy: 0.8550 - val_loss: 0.7810 - val_accuracy: 0.7788
# Epoch 12/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.3475 - accuracy: 0.8776 - val_loss: 0.8146 - val_accuracy: 0.7617
# Epoch 13/30
# 169/169 [==============================] - 5s 28ms/step - loss: 0.2544 - accuracy: 0.9095 - val_loss: 0.8404 - val_accuracy: 0.7862
# Epoch 14/30
# 169/169 [==============================] - 5s 31ms/step - loss: 0.2128 - accuracy: 0.9208 - val_loss: 0.7744 - val_accuracy: 0.8025
# Epoch 15/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.2262 - accuracy: 0.9191 - val_loss: 0.8604 - val_accuracy: 0.7661
# Epoch 16/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.2040 - accuracy: 0.9254 - val_loss: 0.7688 - val_accuracy: 0.8189
# Epoch 17/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.2346 - accuracy: 0.9158 - val_loss: 0.8680 - val_accuracy: 0.7869
# Epoch 18/30
# 169/169 [==============================] - 5s 28ms/step - loss: 0.1818 - accuracy: 0.9286 - val_loss: 0.7431 - val_accuracy: 0.8114
# Epoch 19/30
# 169/169 [==============================] - 5s 31ms/step - loss: 0.1704 - accuracy: 0.9362 - val_loss: 0.8485 - val_accuracy: 0.8151
# Epoch 20/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.1687 - accuracy: 0.9356 - val_loss: 0.9323 - val_accuracy: 0.8077
# Epoch 21/30
# 169/169 [==============================] - 6s 34ms/step - loss: 0.2039 - accuracy: 0.9236 - val_loss: 0.8498 - val_accuracy: 0.7951
# Epoch 22/30
# 169/169 [==============================] - 5s 29ms/step - loss: 0.1658 - accuracy: 0.9347 - val_loss: 0.8641 - val_accuracy: 0.8048
# Epoch 23/30
# 169/169 [==============================] - 5s 28ms/step - loss: 0.1367 - accuracy: 0.9423 - val_loss: 0.8480 - val_accuracy: 0.7862
# Epoch 24/30
# 169/169 [==============================] - 5s 30ms/step - loss: 0.2079 - accuracy: 0.9236 - val_loss: 0.9258 - val_accuracy: 0.7944
# Epoch 25/30
# 169/169 [==============================] - 5s 28ms/step - loss: 0.1345 - accuracy: 0.9460 - val_loss: 0.7930 - val_accuracy: 0.8263
# Epoch 26/30
# 169/169 [==============================] - 6s 35ms/step - loss: 0.1569 - accuracy: 0.9360 - val_loss: 0.8809 - val_accuracy: 0.8166
# Epoch 27/30
# 169/169 [==============================] - 6s 35ms/step - loss: 0.1472 - accuracy: 0.9377 - val_loss: 0.8661 - val_accuracy: 0.8330
# Epoch 28/30
# 169/169 [==============================] - 5s 32ms/step - loss: 0.1353 - accuracy: 0.9445 - val_loss: 0.7864 - val_accuracy: 0.8344
# Epoch 29/30
# 169/169 [==============================] - 6s 37ms/step - loss: 0.1077 - accuracy: 0.9533 - val_loss: 0.7914 - val_accuracy: 0.8344
# Epoch 30/30
# 169/169 [==============================] - 5s 32ms/step - loss: 0.1042 - accuracy: 0.9525 - val_loss: 0.9963 - val_accuracy: 0.8144

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# 1.   Validation accuracy increases post rebalance
# 2.   Model now able to recognise patterns from classes that were under represented.

# %%
### Overall obervations
### Model will overfitt if training data is less
### Real size images need to refit
### Augmentation using image transformation will reduce overfitting
### Drop outs will improve accuracy
### Reducing class imbalance will help improve accuracy

# %% [markdown]
# Overall obervations
#
# 1.   Model will overfit if training data is less
# 2.   Real size images need to refit
# 3.   Augmentation using image transformation will reduce overfitting
# 4.   Drop outs will improve accuracy
# 5.   Reducing class imbalance will help improve accuracy
# 6.   Transfer learning to further improve accuracy
# 7.   Batch size important to optimise memory usage
